# %%
####### Mouting Drive #######
from google.colab import drive
drive.mount('/content/drive')
# !ls

# %% [markdown]
# Installing split-folders

# %%
# !pip install split-folders

# %%
import splitfolders

# %% [markdown]
# Using `splitfolders` the images are split randomly into train:validation:test=70:15:15 proportion

# %%
# Using this the images are split randomly into train:validation:test=70:15:15 proportion

splitfolders.ratio("/content/drive/MyDrive/ES/EX_Dataset& Code/EX_Selfie&Selfie", output="/content/drive/MyDrive/ES/EX_Dataset& Code/train_val_test_split",
    seed=42, ratio=(.7, .15, .15), group_prefix=None)
